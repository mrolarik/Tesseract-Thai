# %% [markdown]
# # Russian Language

# %%
from PIL import Image
import pytesseract

# Russian language
img_path = 'data-text-img/russian.jpg'
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1312x726 at 0x7FDB446E2D50>

# %%
txtImg = Image.open(img_path)
text = pytesseract.image_to_string(txtImg, 'rus')

print text
# Out:
# 1. Поздравляем с благополучным прибытием Подтверждаем
# получение вашего письма в адрес “В” и прочтение письма №21.
# 2. Для организации прикрытия мы дали указание передать
# вам три тысячи местных. Перед тем как их вложить в какое
# либо дело посоветуйтесь ‹: нами, сообщив характеристику
# этого дела.
#
# 3. По вашей просьбе рецептуру изготовления мягкой пленки
# и новостей‘ передадим отдельно вместе с письмом матери.
#
# 4. Гаммы высылать вам рано. Короткие письма шифруйте, а
# побольше—делайте со вставками. Все данные о себе, место
# работы, адрес и т.д. в одной шифровке передавать нельзя.
# Вставки передавайте отдельно.
#
# 5. Посылку жене передали лично. С семьей все благополучно.
# Желаем успеха. Привет от товарищей.
#
# ЫШ/ОЗ Декабря.

# %%
img_path = 'data-text-img/russian-01.jpg'
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=279x180 at 0x7FDB446E23D0>

# %%
txtImg = Image.open(img_path)
text = pytesseract.image_to_string(txtImg, 'rus')

print text
# Out:
# Спрашиваю
# сегодня дочку:
# * У вас в садике топят?
# * Нет, пока только
# В УГОЛ СТЗВЯТ.

# %% [markdown]
# # Greek Language

# %%
img_path = 'data-text-img/greek-01.png'
Image.open(img_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=444x237 at 0x7FDB446E24D0>

# %%
txtImg = Image.open(img_path)
text = pytesseract.image_to_string(txtImg, 'ell')

print text
# Out:
# ΄Ένθ" …… μεν πάντες, &… φύγω α…… δλεθρον,
# ο΄ι΄κοι "ε…, πόλεµόν τε πεφευγότες ήδε θάλασσαν-
# τόν &) οΐον, νόστου κεχρημένον ήδε γυναικός,
# νύµφη των ΄ε'…ε Καλυψώ, δω θείων,
#
# εν …… γλυφυροϊσι, λιλιιιομένη πόσιν εΐναι.
# &… δτε δή ΄έτος ήλθε περιπλομένων ένιαυτών,
#
# τά) ο΄ι έπεκλώσαντο θεο*ι οΐκόνδε νέεσθαι
#
# είς "πω…, οι΄'δ" ΄ένθα πεφυγμένος ήεν όέθλων,
# .… μετά ώ… φίλοισι' θεο*ι &) ελε'…ρον ΐωαντες
# νόσφι Ποσειδάωνος' δ &) άσπερχές μενέαινεν
# άντιθέφ "ο…… πόρος … γώ… ΄ικέσθαι.

# %%
img_path = 'data-text-img/greek-02.png'
Image.open(img_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=575x254 at 0x7FDB446E2B90>

# %%
txtImg = Image.open(img_path)
text = pytesseract.image_to_string(txtImg, 'ell')

print text
# Out:
# ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩΡς15Α
# αβ6γδεζη θθικλµνξοπ ρσςτυφΦχψωΡςΦ%
#
# Α ΒΓΔΕΖΗΘΙΚ/ΙΜΝΞΟΠΡΣΤΥΦΧΨΩΡζΨ-Λ
# αβ6γδεζηθι91κλμνξοπμσ;τυφφχψωβςρ- *?
# ΛΒΓΔΕΖΗΘ|ΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩΓςηήΛ
# αβδγδεζηθθικλµ νξ0πρσςτυφΦχψωΡςοΜ
# ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩΡζ9-Δ
# αβ6γδεζηθ.9ικλμνξ0πρσςτυφψχψω|#ςρ5λ
